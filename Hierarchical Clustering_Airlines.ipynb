# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns





import warnings
warnings.simplefilter("ignore")

# %%
df = pd.read_excel("D:\ExcelR Data Science\Assignments\Clustering\EastWestAirlines.xlsx", sheet_name='data')
df.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
df=df.drop(['ID#','Award?'],axis=1)

# %%
df.head()
# Out:
#    Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    28143           0          1          1          1          174
# 1    19244           0          1          1          1          215
# 2    41354           0          1          1          1         4123
# 3    14776           0          1          1          1          500
# 4    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll
# 0            1                  0                0               7000
# 1            2                  0                0               6968
# 2            4                  0                0               7034
# 3            1                  0                0               6952
# 4           26               2077                4               6935

# %%
df.shape
# Out:
# (3999, 10)

# %%
df.dtypes
# Out:
# Balance              int64
# Qual_miles           int64
# cc1_miles            int64
# cc2_miles            int64
# cc3_miles            int64
# Bonus_miles          int64
# Bonus_trans          int64
# Flight_miles_12mo    int64
# Flight_trans_12      int64
# Days_since_enroll    int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# dtype: int64

# %%
df.describe()
# Out:
#             Balance    Qual_miles    cc1_miles    cc2_miles    cc3_miles  \
# count  3.999000e+03   3999.000000  3999.000000  3999.000000  3999.000000
# mean   7.360133e+04    144.114529     2.059515     1.014504     1.012253
# std    1.007757e+05    773.663804     1.376919     0.147650     0.195241
# min    0.000000e+00      0.000000     1.000000     1.000000     1.000000
# 25%    1.852750e+04      0.000000     1.000000     1.000000     1.000000
# 50%    4.309700e+04      0.000000     1.000000     1.000000     1.000000
# 75%    9.240400e+04      0.000000     3.000000     1.000000     1.000000
# max    1.704838e+06  11148.000000     5.000000     3.000000     5.000000
#
#          Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# count    3999.000000   3999.00000        3999.000000      3999.000000
# mean    17144.846212     11.60190         460.055764         1.373593
# std     24150.967826      9.60381        1400.209171         3.793172
# ...

# %%
plt.figure(figsize=(15,10))
sns.boxplot(data=df)
plt.show()

# %%
def remove_outliers(data):
     
    df = data.copy()
   
    for col in list(df.columns):
        
        Q1 = df[str(col)].quantile(0.05)
        Q3 = df[str(col)].quantile(0.95)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5*IQR
        upper_bound = Q3 + 1.5*IQR
 
        df = df[(df[str(col)] >= lower_bound) & (df[str(col)] <= upper_bound)]
   
        return df

# %%
cleaned_data = remove_outliers(df)

# %%
#Normalizing Dataset

from sklearn.preprocessing import StandardScaler
sd=StandardScaler()
df_scaled=sd.fit_transform(cleaned_data)

# %%
data=pd.DataFrame(df_scaled,columns=df.columns)

# %%
data.head()
# Out:
#     Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0 -0.526340   -0.183689  -0.767032  -0.098566  -0.060929    -0.708790
# 1 -0.642199   -0.183689  -0.767032  -0.098566  -0.060929    -0.707051
# 2 -0.354342   -0.183689  -0.767032  -0.098566  -0.060929    -0.541233
# 3 -0.700369   -0.183689  -0.767032  -0.098566  -0.060929    -0.694958
# 4  0.379920   -0.183689   1.422205  -0.098566  -0.060929     1.121059
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll
# 0    -1.102910          -0.324736        -0.358284           1.407388
# 1    -0.998161          -0.324736        -0.358284           1.391841
# 2    -0.788663          -0.324736        -0.358284           1.423907
# 3    -1.102910          -0.324736        -0.358284           1.384067
# 4     1.515815           1.170823         0.713600           1.375808

# %%
import scipy.cluster.hierarchy as shc
plt.figure(figsize=(10, 7))  
plt.title("Dendrograms")  
dend = shc.dendrogram(shc.linkage(df_scaled, method='ward'))

# %%
plt.figure(figsize=(10, 7))  
plt.title("Dendrograms")  
dend = shc.dendrogram(shc.linkage(df_scaled, method='ward'))
plt.axhline(y=80, color='r', linestyle='--')

# %%
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=6, affinity='euclidean', linkage='ward')  
y_hc=cluster.fit_predict(df_scaled)
labels=cluster.labels_

# %%
labels
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
plt.scatter(df_scaled[labels==0, 0], df_scaled[labels==0, 1], s=50, marker='o', color='red')
plt.scatter(df_scaled[labels==1, 0], df_scaled[labels==1, 1], s=50, marker='o', color='blue')
plt.scatter(df_scaled[labels==2, 0], df_scaled[labels==2, 1], s=50, marker='o', color='green')
plt.scatter(df_scaled[labels==3, 0], df_scaled[labels==3, 1], s=50, marker='o', color='purple')
plt.scatter(df_scaled[labels==4, 0], df_scaled[labels==4, 1], s=50, marker='o', color='orange')
plt.scatter(df_scaled[labels==5, 0], df_scaled[labels==5, 1], s=50, marker='o', color='yellow')
plt.show()

# %%
data['clusters']=pd.array(labels)

# %%
data=data.drop('s',axis=1)

# %%
data['clusters'].unique()
# Out:
# <IntegerArray>
# [1, 0, 3, 2, 5, 4]
# Length: 6, dtype: Int64

# %%
plt.figure(figsize=(10, 7))  
plt.scatter(data['clusters'],data['Balance'], c=labels)
